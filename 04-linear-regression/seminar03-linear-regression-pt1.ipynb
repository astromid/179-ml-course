# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()

# %% [markdown]
# # Закон Гука

# %% [markdown]
# ## Загрузка и визуализация данных

# %%
elasticity_df = pd.read_csv("01-elasticity.csv")
elasticity_df.head()

# %%
elasticity_df.info()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.scatterplot(elasticity_df, x="x", y="F", ax=ax)
ax.set_xlabel("x, m", fontsize=12)
ax.set_ylabel("F, N", fontsize=12)
ax.set_title("Измеренная зависимость силы упругости от величины растяжения", fontsize=18)
plt.show()

# %% [markdown]
# ## Линейная регрессия

# %% [markdown]
# ### Аналитическое решение (одномерная регрессия)

# %%
x = elasticity_df["x"]
y = elasticity_df["F"]

# %% [markdown]
# *Задание: реализуйте подсчет w по формуле*

# %%
# write your code here
w = ...
print(f"k_упр = {w}")

# %% [markdown]
# *Задание: посчитайте значение MSE для полученной прямой*

# %%
# write your code here
mse = ...
print(f"MSE: {mse}")

# %%
np.sqrt(mse)

# %%
# visualize
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(x, w * x, label="predicted", color="green")
sns.scatterplot(elasticity_df, x="x", y="F", label="measured", ax=ax)
ax.set_xlabel("x, m", fontsize=12)
ax.set_ylabel("F, N", fontsize=12)
ax.set_title("Измеренная зависимость силы упругости от величины растяжения", fontsize=18)
plt.show()

# %% [markdown]
# ### Аналитическое решение (многомерная регрессия)

# %%
# bias trick
bias = np.ones_like(x)
X = np.column_stack((bias, x))

print(f"{X.shape = }")

# %% [markdown]
# *Задание: реализуйте решение по формуле для множественной регрессии*

# %%
# write your code here
# tip: use np.linalg.inv for matrix inversion, .T for transpose, @ for matrix multiplication
w = ...
print(f"w0 = {w[0]}, w1 = {w[1]}")

# %% [markdown]
# *Задание: посчитайте MSE для новой прямой, сравните с предыдущим значением*

# %%
mse = ...
print(f"MSE: {mse}")

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(x, w[0] + w[1] * x, label="predicted", color="green")
sns.scatterplot(elasticity_df, x="x", y="F", label="measured", ax=ax)
ax.set_xlabel("x, m", fontsize=12)
ax.set_ylabel("F, N", fontsize=12)
ax.set_title("Измеренная зависимость силы упругости от величины растяжения", fontsize=18)
plt.show()

# %% [markdown]
# ### Реализация из scikit-learn

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression()
model = model.fit(X, y)
y_pred = model.predict(X)

# %%
model.coef_
