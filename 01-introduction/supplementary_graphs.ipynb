# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## ILVSC data

# %%
ilvsc_data = pd.read_csv('data/sota_models.csv')

# %%
ilvsc_data
# Out:
#       year                model  top1_error  params(M)
# 0   2010.0              LCC-SVM        47.1       0.26
# 1   2011.0             SIFT+FVs        44.7       0.06
# 2   2012.0              AlexNet        37.0      60.00
# 3   2013.0             FiveBase        33.7      60.00
# 4   2014.0               VGG-19        25.5     144.00
# 5   2015.0         Inception V3        21.2      25.00
# 6   2016.0     ResNeXt-101 64x4        19.1      83.60
# 7   2017.0            PNASNet-5        17.1      86.10
# 8   2018.0   ResNeXt-101 32x48d        14.6     829.00
# 9   2019.0                BiT-L        12.5    1000.00
# 10  2020.0  MPL-EfficientNet-L2         9.8     480.00
# 11  2021.0            CoAtNet-7         9.1    2440.00
# 12  2022.0                 CoCa         9.0    2100.00
# 13     NaN                Human        20.0        NaN

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax2 = ax.twinx()
sns.barplot(x=ilvsc_data.index, y=ilvsc_data['top1_error'], ax=ax, alpha=0.6)
ax.set_title('% top-1 ошибок на ILSVRC', fontsize=20)
ax.set_xticklabels(ilvsc_data['model'], rotation=35, fontsize=12)

for i, p in enumerate(ax.patches[:-1]):
    ax.annotate(
        f'{2010+i}', (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center', fontsize=16, color='gray', xytext=(0, 10),
        textcoords='offset points'
    )
    ax.annotate(
        f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height() / 2.),
        ha='center', va='center', fontsize=14, color='black', xytext=(0, 0),
        textcoords='offset points'
    )
p = ax.patches[-1]
ax.annotate(
        f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height() / 2.),
        ha='center', va='center', fontsize=14, color='black', xytext=(0, 0),
        textcoords='offset points'
    )
ax.get_yaxis().set_visible(False)

ax2.set_ylabel('Количество параметров (млн.)')
ax2.plot(ilvsc_data.index, ilvsc_data['params(M)'], color=sns.xkcd_rgb['royal blue'], linewidth=1.5, marker='o')
plt.show()

# %% [markdown]
# ## CPU/GPU Perfomance

# %%
perf_data = pd.read_csv('data/cpu_gpu_performance.csv', parse_dates=['Release date'], index_col='Release date', infer_datetime_format=True)
# Out:
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '20/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '26/06/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '27/01/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '28/06/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '22/06/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '16/06/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '26/03/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '22/03/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '19/02/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '17/03/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '21/06/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '21/06/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '18/12/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '24/09/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# /home/astromid/miniconda3/envs/diet-ds/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:1070: UserWarning: Parsing '22/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(

# %%
perf_data.head()
# Out:
#                    Name  SP GFLOPS Device type
# Release date
# 2001-01-07           P4       3.20         CPU
# 2004-01-06           P4       5.60         CPU
# 2006-01-06    Xeon 5140      24.00         CPU
# 2007-01-01        Q6700      85.44         CPU
# 2009-01-01        Q9650      96.00         CPU

# %%
fig, ax = plt.subplots(figsize=(16, 9))
perf_data[perf_data['Device type'] == 'CPU']['SP GFLOPS'].plot(ax=ax, marker='o', color=sns.xkcd_rgb['royal blue'], label='Intel CPU')
perf_data[perf_data['Device type'] == 'GPU']['SP GFLOPS'].plot(ax=ax, marker='o', color=sns.xkcd_rgb['green'], label='NVIDIA GPU')
ax.legend()
for row in perf_data.itertuples():
    ytext = 10 if row[3] == 'GPU' else -10
    ax.annotate(
        row.Name, (row.Index, row[2]), ha='center', va='center',
        fontsize=8, color='gray', xytext=(0, ytext), textcoords='offset points'
    )
ax.set_xlabel('')
ax.set_ylabel('Single-precision GFLOPS')
ax.set_title('Рост производительности CPU и GPU', fontsize=20)
plt.show()

# %% [markdown]
# ## Arxiv stats

# %%
arxiv_data = pd.read_csv('data/arxiv_stats.csv', index_col='year')

# %%
arxiv_data
# Out:
#       count
# year
# 2009    327
# 2010    537
# 2011    726
# 2012   1686
# 2013   1920
# 2014   2564
# 2015   3816
# 2016   6073
# 2017   9182
# 2018  15428
# 2019  25335
# 2020  42242

# %%
fig, ax = plt.subplots(figsize=(16, 9))
arxiv_data['count'].plot(ax=ax, marker='o', color=sns.xkcd_rgb['royal blue'])
ax.set_xlabel('')
ax.set_ylabel('Количество статей')
ax.set_title('Рост количества публикаций в области AI на ArXiv', fontsize=20)
plt.show()

# %% [markdown]
# ## Websites data

# %%
websites_data = pd.read_csv('data/websites_stats.csv', index_col='year')

# %%
websites_data
# Out:
#         websites
# year
# 1991           1
# 1992          10
# 1993         130
# 1994        2738
# 1995       23500
# 1996      257601
# 1997     1117255
# 1998     2410067
# 1999     3177453
# 2000    17087182
# 2001    29254370
# 2002    38760373
# 2003    40912332
# 2004    51611646
# 2005    64780617
# 2006    85507314
# 2007   121892559
# 2008   172338726
# 2009   238027855
# 2010   206956723
# 2011   346004403
# 2012   697089489
# 2013   672985183
# 2014   968882453
# 2015   863105652
# 2016  1045543808
# 2017  1766926408
# 2018  1630322579
# 2020  1828849200

# %%
fig, ax = plt.subplots(figsize=(16, 9))
websites_data['websites'].plot(ax=ax, marker='o', color=sns.xkcd_rgb['royal blue'])
ax.set_xlabel('')
ax.set_ylabel('Количество сайтов')
ax.set_title('Рост количества сайтов в Интернете', fontsize=20)
plt.show()
